# %% [markdown]
# # Definitions

# %%
# !git clone https://github.com/Text-Mining/Useful-Corpora-for-Text-Mining-in-Persian-Language.git
# !unrar x '/content/Useful-Corpora-for-Text-Mining-in-Persian-Language/News/FarsNews 97/farsnews.part01.rar'
# !pip install hazm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hazm
#   Downloading hazm-0.7.0-py3-none-any.whl (316 kB)
#      |████████████████████████████████| 316 kB 14.7 MB/s
# Collecting libwapiti>=0.2.1
#   Downloading libwapiti-0.2.1.tar.gz (233 kB)
#      |████████████████████████████████| 233 kB 59.8 MB/s
# Collecting nltk==3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 61.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk==3.3->hazm) (1.15.0)
# Building wheels for collected packages: nltk, libwapiti
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394487 sha256=59cd0906adc04d7a0ac4c3aa8711113213eb1414d0b7c9cd54cd3ba2a7e6fb47
#   Stored in directory: /root/.cache/pip/wheels/9b/fd/0c/d92302c876e5de87ebd7fc0979d82edb93e2d8d768bf71fac4
#   Building wheel for libwapiti (setup.py) ... done
#   Created wheel for libwapiti: filename=libwapiti-0.2.1-cp37-cp37m-linux_x86_64.whl size=154648 sha256=483d33f0f4b616aab3a5fa0013de279d4eecc390eec5926e623649eb103c28d7
#   Stored in directory: /root/.cache/pip/wheels/ab/b2/5b/0fe4b8f5c0e65341e8ea7bb3f4a6ebabfe8b1ac31322392dbf
# Successfully built nltk libwapiti
# Installing collected packages: nltk, libwapiti, hazm
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# Successfully installed hazm-0.7.0 libwapiti-0.2.1 nltk-3.3

# %%
import pandas as pd
import numpy as np
import json
import ast
import math
from scipy import spatial
from threading import Thread
import hazm as hzm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
def normalizer(data):
    """
    data: a row of the dataframe
    """
    normalizer = hzm.Normalizer()
    return normalizer.normalize(data)


def stemmer(data):
    stemmer = hzm.Stemmer()
    stem_list = []
    for i in data:
        stem_list.append(stemmer.stem(i))
    return stem_list


def lemma(text_tokens):
    lemmatizer = hzm.Lemmatizer()
    temp = []
    for word in text_tokens:
        temp.append(lemmatizer.lemmatize(word))

    return temp


def removeStopWords(text_tokens):
    tokens_without_sw = [
        word for word in text_tokens if not word in hzm.stopwords_list()
    ]
    return tokens_without_sw


def remove_punctuations(text_tokens):
    punctuations_list = [
        "،",
        ".",
        ":",
        "؛",
        "؟",
        "!",
        "'",
        "\\",
        "/",
        "-",
        "ـ",
        "+",
        "=",
        "*",
        ",",
        "٪",
        "$",
        "#",
        "@",
        "÷",
        "<",
        ">",
        "|",
        "}",
        "{",
        "[",
        "]",
        ")",
        "(",
        "…",
    ]
    delimiters_list = [
        "،",
        ".",
        ":",
        "؛",
        "؟",
        "!",
        "'",
        "\\",
        "/",
        "-",
        "ـ",
        ",",
        "|",
        "}",
        "{",
        "[",
        "]",
        ")",
        "(",
        "…",
    ]

    tokens_without_punc = []
    for token in text_tokens:
        if token not in punctuations_list:
            """
            the following for-loop is to replace 
            the punctuations appearing in the middle
            of tokens with a space so we can later
            split the tokens by space and separately
            extract the words
            """
            for delimiter in delimiters_list:
                token = token.replace(delimiter, " ")

            for word in token.split():
                tokens_without_punc.append(word.strip())

    return tokens_without_punc


def preprocess_pipeline(
    df,
    normalize_flag=True,
    remove_stop_words_flag=False,
    remove_punctuations_flag=False,
    lemmatize_flag=False,
    stemmer_flag=False,
    show_logs=False,
):
    """
    input text 
        ↳ [normalize]
            ↳ tokenize
                ↳ [remove punctuations] 
                    ↳ [remove stop words]
                        ↳ [lemmatize]
                            ↳ [stemmer]
                                ↳ output text
    """
    df["preprocessed"] = None
    for index in df.index:
        text = df.loc[index, "NewsBody"]
        if normalize_flag:
            text = normalizer(df["NewsBody"][index])

        text_tokens = hzm.word_tokenize(text)

        if remove_punctuations_flag:
            text_tokens = remove_punctuations(text_tokens)

        if remove_stop_words_flag:
            text_tokens = removeStopWords(text_tokens)

        if lemmatize_flag:
            text_tokens = lemma(text_tokens)

        if stemmer_flag:
            text_tokens = stemmer(text_tokens)
        
        df["preprocessed"][index] = "/".join(text_tokens)

        if show_logs:
            print(f"Preprocessed {index}")

    return df


def token_invert_indexing(df, tokens):
    inverted_index = {
        "Term": [],
        "Total_Ferquency":[],
        "DocID_Ferquency": []
    }
    text_tokens = df.loc[0, "preprocessed"]
    tokens = text_tokens.split("/")
    for token in tokens:
        each_term_per_document_frequency = {}
        sum = 0
        for index in df.index:
            text_tokens = df.loc[index, "preprocessed"]
            news_body_array = text_tokens.split("/")
            if(token in set(news_body_array)):
                count = news_body_array.count(token)
                each_term_per_document_frequency[index] = count
                sum += count
        if token.replace(" ", "") != "" :
            inverted_index["Term"].append(token)
            inverted_index["ُTotal_Ferquency"].append(sum)
            inverted_index["DocID_Ferquency"].append(each_term_per_document_frequency) 
    return inverted_index


def invert_indexing(df):
    terms = []
    inverted_index = {
        "Term": [],
        "Total_Ferquency":[],
        "DocID_Ferquency": []
    }

    for index in df.index:
        text_tokens = df.loc[index, "preprocessed"]
        terms.extend(list(set(text_tokens.split("/"))))
    
    terms = set(terms)
    
    print(len(terms))

    kl = 0
    for token in terms:
        each_term_per_document_frequency = {}
        sum = 0
        for index in df.index:
            text_tokens = df.loc[index, "preprocessed"]
            news_body_array = text_tokens.split("/")
            if(token in set(news_body_array)):
                count = news_body_array.count(token)
                each_term_per_document_frequency[index] = count
                sum += count
        if token.replace(" ", "") != "" :
            inverted_index["Term"].append(token)
            inverted_index["Total_Ferquency"].append(sum)
            inverted_index["DocID_Ferquency"].append(each_term_per_document_frequency)                
        # if show_logs:
        kl += 1
        print(f"Inverted indexing {(kl/len(terms)*100)} %")

    return inverted_index



def retrieve_documents(preprocessed_df, inverted_index, query, weighting_model):
    docs_titles = []
    docs_index = inverted_index.get(query, [])
    for doc_index in docs_index:
        docs_titles.append(preprocessed_df.loc[doc_index, "NewsTitle"])

    return docs_titles


def get_query(preprocessed_df, inverted_index, number_of_documents):
    query = input("Enter your query: ").strip()
    weighting_model = input("Enter your Weighting model: (e.g. : ddd.qqq) ").strip()
    if(weighting_model == ""):
        weighting_model = "lnc.ltc" # default weighting model
    k = int(input("How many Document do you want to Retrive : ").strip())
    while query != "":
        # the end condition is when the
        # user enters an empty string for query
        output = []

        doc_tf_method = weighting_model[0]
        doc_df_method = weighting_model[1]
        doc_norm_method = weighting_model[2]

        query_tf_method = weighting_model[4]
        query_df_method = weighting_model[5]
        query_norm_method = weighting_model[6]

        query_df = pd.DataFrame({"NewsBody": [query], "preprocessed": [""],})
        preprocessed_query = preprocess_pipeline(query_df, True, True, True, True, True, True)
        processed_query = preprocessed_query.loc[0, "preprocessed"]



        matrix_vectorization = TfidfVectorizer()
        transformed_matrix = matrix_vectorization.fit_transform(preprocessed_df['preprocessed'].append(pd.Series([processed_query], name="preprocessed")))

        similarity = cosine_similarity(transformed_matrix[-1], transformed_matrix)[0][:-1]
        maxim_array = np.argmax(similarity)
        guess = 
        for i in maxim_array :
            print(i, " :::::: ", preprocessed_df.iloc[i])
            print("----------------------------------------------------------")
            # similarity = np.argwhere(maxim > x)


        query_invert_indexing = token_invert_indexing(preprocessed_df, processed_query)
        # query_tokens_array = processed_query.split("/")
        # for term in query_tokens_array:
        #     tf_idf (inverted_index, term, doc_Id, number_of_documents, tf_method, df_method)

        # print(f"Processed query: {processed_query}")

        # docs_titles = retrieve_documents(preprocessed_df, inverted_index, query, weighting_model)
        # print(docs_titles)
        # print(f"Retrieved {len(docs_titles)} documents")

        query = input("\nEnter your query: ").strip()
        if(query != ""):
            weighting_model = input("Enter your Weighting model: (e.g. : ddd.qqq) ").strip()
            if(weighting_model == ""):
                weighting_model = "lnc.ltc" # default weighting model
            k = int(input("How many Document do you want to Retrive : ").strip())



def term_frequency(method, word_dictionary):
    if(method == 'n'):
        return word_dictionary['term']['doc_Id']
    if(method == 'l'):
        return (1 + math.log(word_dictionary['term']['doc_Id'], 10))
    if(method == 'a'):
        return (0.5 + ((0.5 * word_dictionary['term']['doc_Id'])/(word_dictionary['term']['*']).max))
    if(method == 'b'):
        if word_dictionary['term']['doc_Id'] > 1 :
            return 1
        else :
            return 0
    if(method == 'L'):
        ave = word_dictionary['term']['*']
        return ((1 + math.log(word_dictionary['term']['doc_Id'], 10))/(1 + math.log(ave , 10)))

def inverse_document_frequency(method, word_dictionary, number_of_documents):
    if(method == 'n'):
        return 1
    if(method == 't'):
        return math.log(number_of_documents/len(word_dictionary['term']), 10)
    if(method == 'p'):
        return max(0, math.log(number_of_documents - (len(word_dictionary['term'])) / len(word_dictionary['term'] )))

def normalization(method, w):
    if(method == 'n'):
        return 1
    if(method == 'c'):
        sum = 0
        for i in range(len(w)):
            sum += w[i] ** 2
        return (1 / math.sqrt(sum))
    if(method == 'u'):
        pivot = 5
        return (1 / pivot)
    if(method == 'b'):
        return 1
    

def tf_idf (word_dictionary, term, doc_Id, number_of_documents, tf_method, df_method):
    tf = term_frequency(tf_method, word_dictionary)
    idf = inverse_document_frequency(df_method, word_dictionary, number_of_documents)
    return tf * idf 

def boolean_model (word_dictionary, number_of_documents):
    existance_matrix = np.zero(np.zeros((len(word_dictionary['term']), number_of_documents)))
    for i, token in enumerate(word_dictionary['term']):
        for j, doc_Id in enumerate(word_dictionary['doc_Id'] in keys):
            existance_matrix[i, j] = 1
    
    return existance_matrix


def ranking(vector_query, vector_doc_tf_idf, normalization_method, k):
    cosine_distances = []

    for i in range(vector_doc_tf_idf.shape[0]):
        try:
            z = spatial.distance.cosine(vector_doc_tf_idf[i], vector_query)
            cosine_distances.append(z.item())
        except Exception as e:
            print(e)

    cosine_distances = np.array(cosine_distances)

    top_matches_indices = np.argsort(cosine_distances, axis=0)[:k]
    return top_matches_indices, cosine_distances[top_matches_indices]

# %% [markdown]
# # Codes

# %% [markdown]
# Converting json news file to csv file

# %%
data_dic = {
    "Id": [],
    "CategoryEn1": [],
    "CategoryFa1": [],
    "CategoryEn2": [],
    "CategoryFa2": [],
    "NewsDate": [],
    "NewsTitle": [],
    "NewsSummary": [],
    "NewsBody": [],
}

comment = {
    "newsID": [],
    "id": [],
    "parentID": [],
    "parentName": [],
    "name": [],
    "createDate": [],
    "persianCreateDate": [],
    "text": [],
}

id_news = 0
with open('/content/farsnews.json', encoding='utf-8-sig') as document:
    for line in document:
        
        data = json.loads(line)
        # ID
        data_dic["Id"].append(id_news)
        
        # Category panel
        try:
            cp = data["CategoryPanel"]

            data_dic['CategoryEn1'].append(cp[0]["CategoryEn"].encode('utf-8-sig').decode('utf-8'))
            data_dic['CategoryEn2'].append(cp[1]["CategoryEn"].encode('utf-8-sig').decode('utf-8'))

            data_dic['CategoryFa1'].append(cp[0]["CategoryFa"].encode('utf-8-sig').decode('utf-8'))
            data_dic['CategoryFa2'].append(cp[1]["CategoryFa"].encode('utf-8-sig').decode('utf-8'))

        except:
            try:
                ce = data["CategoryEn"].encode('utf-8-sig').decode('utf-8')
                cf = data["CategoryFa"].encode('utf-8-sig').decode('utf-8')
                data_dic['CategoryEn1'].append(ce)
                data_dic['CategoryFa1'].append(cf)

                data_dic['CategoryEn2'].append("None")
                data_dic['CategoryFa2'].append("None")
            except:
                cp = "None"
                data_dic['CategoryEn1'].append(cp)
                data_dic['CategoryEn2'].append(cp)
                data_dic['CategoryFa1'].append(cp)
                data_dic['CategoryFa2'].append(cp)


        # News Date
        try:
            newsdate = str(data["NewsDate"]).encode('utf-8-sig').decode('utf-8').rstrip()
            data_dic["NewsDate"].append(newsdate)
        except:
            data_dic["NewsDate"].append("None")
        
        # News Title

        try:
            newstitle = str(data["NewsTitle"].encode('utf-8-sig').decode('utf-8'))
            data_dic["NewsTitle"].append(newstitle)
        except:
            data_dic["NewsTitle"].append("None")
        
        # News Summary
        try:
            newssummery = str(data["NewsSummary"].encode('utf-8-sig').decode('utf-8'))
            data_dic["NewsSummary"].append(newssummery)
        except:
            data_dic["NewsSummary"].append("None")
        

        # News Body
        try:
            newsbody = str(data["NewsBody"].encode('utf-8-sig').decode('utf-8'))
            data_dic["NewsBody"].append(newsbody)
        except:
            data_dic["NewsBody"].append("None")

        # Comment

        # try:
        #     comments = data["GetComments"]["CommentsJsonArray"]
        #     for i in range(0, len(comments)):
        #         comment["newsID"].append(id_news)
        #         comment["id"].append(comment['id'])
        #         comment[]
                
        # except:
        #     pass


        # Update id news for table
        id_news = id_news + 1

        # Show Status
        if id_news % 200 == 0:
            print(f"{id_news} completed!")

data_frame = pd.DataFrame(data_dic)
data_frame.to_csv("News.csv")

# %%
news_pd = pd.read_csv("/content/gdrive/MyDrive/News.csv")
x = preprocess_pipeline(news_pd)
data_dic = invert_indexing(x, True)
data_frame = pd.DataFrame(data_dic)
data_frame.to_csv("/content/gdrive/MyDrive/PreProcessedNews.csv")

# %% [markdown]
# Creating Inverted Index

# %%
news_df = pd.read_csv("/content/gdrive/MyDrive/PreProcessedNews.csv")
news_df = news_df.iloc[:1000,:]
inverted_index_dict = invert_indexing(news_df)

inverted_index_df = pd.DataFrame().from_dict(inverted_index_dict)
inverted_index_df.to_csv("/content/gdrive/MyDrive/Posting_Lists.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# Inverted indexing 78.15122377622377 %
# Inverted indexing 78.15559440559441 %
# Inverted indexing 78.15996503496504 %
# Inverted indexing 78.16433566433567 %
# Inverted indexing 78.1687062937063 %
# Inverted indexing 78.17307692307692 %
# Inverted indexing 78.17744755244756 %
# Inverted indexing 78.18181818181819 %
# Inverted indexing 78.1861888111888 %
# Inverted indexing 78.19055944055944 %
# Inverted indexing 78.19493006993007 %
# Inverted indexing 78.1993006993007 %
# Inverted indexing 78.20367132867133 %
# Inverted indexing 78.20804195804196 %
# Inverted indexing 78.21241258741259 %
# Inverted indexing 78.21678321678321 %
# Inverted indexing 78.22115384615384 %
# Inverted indexing 78.22552447552448 %
# Inverted indexing 78.2298951048951 %
# Inverted indexing 78.23426573426573 %
# Inverted indexing 78.23863636363636 %
# Inverted indexing 78.24300699300699 %
# Inverted indexing 78.24737762237763 %
# Inverted indexing 78.25174825174825 %
# Inverted indexing 78.25611888111888 %
# Inverted indexing 78.2604895104895 %
# Inverted indexing 78.26486013986013 %
# Inverted indexing 78.26923076923077 %
# Inverted indexing 78.2736013986014 %
# Inverted indexing 78.27797202797203 %
# Inverted indexing 78.28234265734267 %
# Inverted indexing 78.28671328671328 %
# Inverted indexing 78.29108391608392 %
# Inverted indexing 78.29545454545455 %
# Inverted indexing 78.29982517482517 %
# Inverted indexing 78.30419580419581 %
# Inverted indexing 78.30856643356643 %
# Inverted indexing 78.31293706293707 %
# Inverted indexing 78.3173076923077 %
# Inverted indexing 78.32167832167832 %
# Inverted indexing 78.32604895104896 %
# Inverted indexing 78.33041958041959 %
# Inverted indexing 78.3347902097902 %
# Inverted indexing 78.33916083916084 %
# Inverted indexing 78.34353146853147 %
# Inverted indexing 78.34790209790211 %
# Inverted indexing 78.35227272727273 %
# Inverted indexing 78.35664335664335 %
# Inverted indexing 78.36101398601399 %
# Inverted indexing 78.36538461538461 %
# Inverted indexing 78.36975524475524 %
# Inverted indexing 78.37412587412588 %
# Inverted indexing 78.3784965034965 %
# Inverted indexing 78.38286713286713 %
# Inverted indexing 78.38723776223776 %
# Inverted indexing 78.39160839160839 %
# Inverted indexing 78.39597902097903 %
# Inverted indexing 78.40034965034965 %
# Inverted indexing 78.40472027972028 %
# Inverted indexing 78.4090909090909 %
# Inverted indexing 78.41346153846153 %
# Inverted indexing 78.41783216783217 %
# Inverted indexing 78.4222027972028 %
# Inverted indexing 78.42657342657343 %
# Inverted indexing 78.43094405594405 %
# Inverted indexing 78.43531468531468 %
# Inverted indexing 78.43968531468532 %
# Inverted indexing 78.44405594405595 %
# Inverted indexing 78.44842657342657 %
# Inverted indexing 78.4527972027972 %
# Inverted indexing 78.45716783216783 %
# Inverted indexing 78.46153846153847 %
# Inverted indexing 78.4659090909091 %
# Inverted indexing 78.47027972027972 %
# Inverted indexing 78.47465034965036 %
# Inverted indexing 78.47902097902097 %
# Inverted indexing 78.4833916083916 %
# Inverted indexing 78.48776223776224 %
# Inverted indexing 78.49213286713287 %
# Inverted indexing 78.4965034965035 %
# Inverted indexing 78.50087412587412 %
# Inverted indexing 78.50524475524475 %
# Inverted indexing 78.50961538461539 %
# Inverted indexing 78.51398601398601 %
# Inverted indexing 78.51835664335664 %
# Inverted indexing 78.52272727272728 %
# Inverted indexing 78.52709790209789 %
# Inverted indexing 78.53146853146853 %
# Inverted indexing 78.53583916083916 %
# Inverted indexing 78.54020979020979 %
# Inverted indexing 78.54458041958043 %
# Inverted indexing 78.54895104895104 %
# Inverted indexing 78.55332167832168 %
# Inverted indexing 78.5576923076923 %
# Inverted indexing 78.56206293706293 %
# Inverted indexing 78.56643356643357 %
# Inverted indexing 78.5708041958042 %
# Inverted indexing 78.57517482517483 %
# Inverted indexing 78.57954545454545 %
# Inverted indexing 78.58391608391608 %
# Inverted indexing 78.58828671328672 %
# Inverted indexing 78.59265734265735 %
# Inverted indexing 78.59702797202797 %
# Inverted indexing 78.6013986013986 %
# Inverted indexing 78.60576923076923 %
# Inverted indexing 78.61013986013987 %
# Inverted indexing 78.6145104895105 %
# Inverted indexing 78.61888111888112 %
# Inverted indexing 78.62325174825175 %
# Inverted indexing 78.62762237762237 %
# Inverted indexing 78.631993006993 %
# Inverted indexing 78.63636363636364 %
# Inverted indexing 78.64073426573427 %
# Inverted indexing 78.64510489510491 %
# Inverted indexing 78.64947552447552 %
# Inverted indexing 78.65384615384615 %
# Inverted indexing 78.65821678321679 %
# Inverted indexing 78.66258741258741 %
# Inverted indexing 78.66695804195804 %
# Inverted indexing 78.67132867132867 %
# Inverted indexing 78.67569930069929 %
# Inverted indexing 78.68006993006993 %
# Inverted indexing 78.68444055944056 %
# Inverted indexing 78.68881118881119 %
# Inverted indexing 78.69318181818183 %
# Inverted indexing 78.69755244755244 %
# Inverted indexing 78.70192307692308 %
# Inverted indexing 78.7062937062937 %
# Inverted indexing 78.71066433566433 %
# Inverted indexing 78.71503496503497 %
# Inverted indexing 78.71940559440559 %
# Inverted indexing 78.72377622377623 %
# Inverted indexing 78.72814685314685 %
# Inverted indexing 78.73251748251748 %
# Inverted indexing 78.73688811188812 %
# Inverted indexing 78.74125874125875 %
# Inverted indexing 78.74562937062936 %
# Inverted indexing 78.75 %
# Inverted indexing 78.75437062937063 %
# Inverted indexing 78.75874125874127 %
# Inverted indexing 78.7631118881119 %
# Inverted indexing 78.7674825174825 %
# Inverted indexing 78.77185314685315 %
# Inverted indexing 78.77622377622377 %
# Inverted indexing 78.7805944055944 %
# Inverted indexing 78.78496503496504 %
# Inverted indexing 78.78933566433567 %
# Inverted indexing 78.7937062937063 %
# Inverted indexing 78.79807692307692 %
# Inverted indexing 78.80244755244755 %
# Inverted indexing 78.80681818181819 %
# Inverted indexing 78.81118881118881 %
# Inverted indexing 78.81555944055944 %
# Inverted indexing 78.81993006993007 %
# Inverted indexing 78.8243006993007 %
# Inverted indexing 78.82867132867133 %
# Inverted indexing 78.83304195804196 %
# Inverted indexing 78.83741258741259 %
# Inverted indexing 78.84178321678321 %
# Inverted indexing 78.84615384615384 %
# Inverted indexing 78.85052447552448 %
# Inverted indexing 78.8548951048951 %
# Inverted indexing 78.85926573426573 %
# Inverted indexing 78.86363636363637 %
# Inverted indexing 78.86800699300699 %
# Inverted indexing 78.87237762237763 %
# Inverted indexing 78.87674825174825 %
# Inverted indexing 78.88111888111888 %
# Inverted indexing 78.88548951048952 %
# Inverted indexing 78.88986013986013 %
# Inverted indexing 78.89423076923077 %
# Inverted indexing 78.8986013986014 %
# Inverted indexing 78.90297202797203 %
# Inverted indexing 78.90734265734267 %
# Inverted indexing 78.9117132867133 %
# Inverted indexing 78.9160839160839 %
# Inverted indexing 78.92045454545455 %
# Inverted indexing 78.92482517482517 %
# Inverted indexing 78.9291958041958 %
# Inverted indexing 78.93356643356644 %
# Inverted indexing 78.93793706293705 %
# Inverted indexing 78.9423076923077 %
# Inverted indexing 78.94667832167832 %
# Inverted indexing 78.95104895104895 %
# Inverted indexing 78.95541958041959 %
# Inverted indexing 78.95979020979021 %
# Inverted indexing 78.96416083916084 %
# Inverted indexing 78.96853146853147 %
# Inverted indexing 78.9729020979021 %
# Inverted indexing 78.97727272727273 %
# Inverted indexing 78.98164335664336 %
# Inverted indexing 78.98601398601399 %
# Inverted indexing 78.99038461538461 %
# Inverted indexing 78.99475524475524 %
# Inverted indexing 78.99912587412588 %
# Inverted indexing 79.0034965034965 %
# Inverted indexing 79.00786713286713 %
# Inverted indexing 79.01223776223776 %
# Inverted indexing 79.01660839160839 %
# Inverted indexing 79.02097902097903 %
# Inverted indexing 79.02534965034965 %
# Inverted indexing 79.02972027972028 %
# Inverted indexing 79.0340909090909 %
# Inverted indexing 79.03846153846153 %
# Inverted indexing 79.04283216783216 %
# Inverted indexing 79.0472027972028 %
# Inverted indexing 79.05157342657343 %
# Inverted indexing 79.05594405594407 %
# Inverted indexing 79.06031468531468 %
# Inverted indexing 79.0646853146853 %
# Inverted indexing 79.06905594405595 %
# Inverted indexing 79.07342657342657 %
# Inverted indexing 79.0777972027972 %
# Inverted indexing 79.08216783216783 %
# Inverted indexing 79.08653846153845 %
# Inverted indexing 79.0909090909091 %
# Inverted indexing 79.09527972027972 %
# Inverted indexing 79.09965034965035 %
# Inverted indexing 79.10402097902099 %
# Inverted indexing 79.1083916083916 %
# Inverted indexing 79.11276223776224 %
# Inverted indexing 79.11713286713287 %
# Inverted indexing 79.1215034965035 %
# Inverted indexing 79.12587412587413 %
# Inverted indexing 79.13024475524476 %
# Inverted indexing 79.13461538461539 %
# Inverted indexing 79.13898601398601 %
# Inverted indexing 79.14335664335664 %
# Inverted indexing 79.14772727272728 %
# Inverted indexing 79.1520979020979 %
# Inverted indexing 79.15646853146853 %
# Inverted indexing 79.16083916083916 %
# Inverted indexing 79.16520979020979 %
# Inverted indexing 79.16958041958043 %
# Inverted indexing 79.17395104895105 %
# Inverted indexing 79.17832167832168 %
# Inverted indexing 79.1826923076923 %
# Inverted indexing 79.18706293706293 %
# Inverted indexing 79.19143356643357 %
# Inverted indexing 79.1958041958042 %
# Inverted indexing 79.20017482517483 %
# Inverted indexing 79.20454545454545 %
# Inverted indexing 79.20891608391608 %
# Inverted indexing 79.2132867132867 %
# Inverted indexing 79.21765734265735 %
# Inverted indexing 79.22202797202797 %
# Inverted indexing 79.2263986013986 %
# Inverted indexing 79.23076923076923 %
# Inverted indexing 79.23513986013985 %
# Inverted indexing 79.2395104895105 %
# Inverted indexing 79.24388111888112 %
# Inverted indexing 79.24825174825175 %
# Inverted indexing 79.25262237762237 %
# Inverted indexing 79.256993006993 %
# Inverted indexing 79.26136363636364 %
# Inverted indexing 79.26573426573427 %
# Inverted indexing 79.2701048951049 %
# Inverted indexing 79.27447552447553 %
# Inverted indexing 79.27884615384615 %
# Inverted indexing 79.28321678321679 %
# Inverted indexing 79.28758741258741 %
# Inverted indexing 79.29195804195804 %
# Inverted indexing 79.29632867132868 %
# Inverted indexing 79.30069930069929 %
# Inverted indexing 79.30506993006993 %
# Inverted indexing 79.30944055944056 %
# Inverted indexing 79.31381118881119 %
# Inverted indexing 79.31818181818183 %
# Inverted indexing 79.32255244755245 %
# Inverted indexing 79.32692307692307 %
# Inverted indexing 79.3312937062937 %
# Inverted indexing 79.33566433566433 %
# Inverted indexing 79.34003496503496 %
# Inverted indexing 79.3444055944056 %
# Inverted indexing 79.34877622377621 %
# Inverted indexing 79.35314685314685 %
# Inverted indexing 79.35751748251748 %
# Inverted indexing 79.3618881118881 %
# Inverted indexing 79.36625874125875 %
# Inverted indexing 79.37062937062937 %
# Inverted indexing 79.375 %
# Inverted indexing 79.37937062937063 %
# Inverted indexing 79.38374125874125 %
# Inverted indexing 79.3881118881119 %
# Inverted indexing 79.39248251748252 %
# Inverted indexing 79.39685314685315 %
# Inverted indexing 79.40122377622377 %
# Inverted indexing 79.4055944055944 %
# Inverted indexing 79.40996503496504 %
# Inverted indexing 79.41433566433567 %
# Inverted indexing 79.4187062937063 %
# Inverted indexing 79.42307692307692 %
# Inverted indexing 79.42744755244755 %
# Inverted indexing 79.43181818181819 %
# Inverted indexing 79.43618881118881 %
# Inverted indexing 79.44055944055944 %
# Inverted indexing 79.44493006993008 %
# Inverted indexing 79.4493006993007 %
# Inverted indexing 79.45367132867133 %
# Inverted indexing 79.45804195804196 %
# Inverted indexing 79.46241258741259 %
# Inverted indexing 79.46678321678323 %
# Inverted indexing 79.47115384615384 %
# Inverted indexing 79.47552447552447 %
# Inverted indexing 79.4798951048951 %
# Inverted indexing 79.48426573426573 %
# Inverted indexing 79.48863636363637 %
# Inverted indexing 79.493006993007 %
# Inverted indexing 79.49737762237761 %
# Inverted indexing 79.50174825174825 %
# Inverted indexing 79.50611888111888 %
# Inverted indexing 79.5104895104895 %
# Inverted indexing 79.51486013986015 %
# Inverted indexing 79.51923076923076 %
# Inverted indexing 79.5236013986014 %
# Inverted indexing 79.52797202797203 %
# Inverted indexing 79.53234265734265 %
# Inverted indexing 79.5367132867133 %
# Inverted indexing 79.54108391608392 %
# Inverted indexing 79.54545454545455 %
# Inverted indexing 79.54982517482517 %
# Inverted indexing 79.5541958041958 %
# Inverted indexing 79.55856643356644 %
# Inverted indexing 79.56293706293707 %
# Inverted indexing 79.5673076923077 %
# Inverted indexing 79.57167832167832 %
# Inverted indexing 79.57604895104895 %
# Inverted indexing 79.58041958041959 %
# Inverted indexing 79.58479020979021 %
# Inverted indexing 79.58916083916084 %
# Inverted indexing 79.59353146853147 %
# Inverted indexing 79.5979020979021 %
# Inverted indexing 79.60227272727273 %
# Inverted indexing 79.60664335664336 %
# Inverted indexing 79.61101398601399 %
# Inverted indexing 79.61538461538461 %
# Inverted indexing 79.61975524475524 %
# Inverted indexing 79.62412587412587 %
# Inverted indexing 79.6284965034965 %
# Inverted indexing 79.63286713286713 %
# Inverted indexing 79.63723776223776 %
# Inverted indexing 79.64160839160839 %
# Inverted indexing 79.64597902097901 %
# Inverted indexing 79.65034965034965 %
# Inverted indexing 79.65472027972028 %
# Inverted indexing 79.6590909090909 %
# Inverted indexing 79.66346153846153 %
# Inverted indexing 79.66783216783216 %
# Inverted indexing 79.6722027972028 %
# Inverted indexing 79.67657342657343 %
# Inverted indexing 79.68094405594405 %
# Inverted indexing 79.6853146853147 %
# Inverted indexing 79.6896853146853 %
# Inverted indexing 79.69405594405595 %
# Inverted indexing 79.69842657342657 %
# Inverted indexing 79.7027972027972 %
# Inverted indexing 79.70716783216784 %
# Inverted indexing 79.71153846153847 %
# Inverted indexing 79.7159090909091 %
# Inverted indexing 79.72027972027972 %
# Inverted indexing 79.72465034965035 %
# Inverted indexing 79.72902097902099 %
# Inverted indexing 79.73339160839161 %
# Inverted indexing 79.73776223776224 %
# Inverted indexing 79.74213286713287 %
# Inverted indexing 79.7465034965035 %
# Inverted indexing 79.75087412587413 %
# Inverted indexing 79.75524475524476 %
# Inverted indexing 79.75961538461539 %
# Inverted indexing 79.76398601398601 %
# Inverted indexing 79.76835664335664 %
# Inverted indexing 79.77272727272727 %
# Inverted indexing 79.7770979020979 %
# Inverted indexing 79.78146853146853 %
# Inverted indexing 79.78583916083916 %
# Inverted indexing 79.79020979020979 %
# Inverted indexing 79.79458041958041 %
# Inverted indexing 79.79895104895105 %
# Inverted indexing 79.80332167832168 %
# Inverted indexing 79.8076923076923 %
# Inverted indexing 79.81206293706293 %
# Inverted indexing 79.81643356643356 %
# Inverted indexing 79.8208041958042 %
# Inverted indexing 79.82517482517483 %
# Inverted indexing 79.82954545454545 %
# Inverted indexing 79.83391608391608 %
# Inverted indexing 79.8382867132867 %
# Inverted indexing 79.84265734265735 %
# Inverted indexing 79.84702797202797 %
# Inverted indexing 79.8513986013986 %
# Inverted indexing 79.85576923076924 %
# Inverted indexing 79.86013986013985 %
# Inverted indexing 79.8645104895105 %
# Inverted indexing 79.86888111888112 %
# Inverted indexing 79.87325174825175 %
# Inverted indexing 79.87762237762239 %
# Inverted indexing 79.881993006993 %
# Inverted indexing 79.88636363636363 %
# Inverted indexing 79.89073426573427 %
# Inverted indexing 79.8951048951049 %
# Inverted indexing 79.89947552447553 %
# Inverted indexing 79.90384615384616 %
# Inverted indexing 79.90821678321677 %
# Inverted indexing 79.91258741258741 %
# Inverted indexing 79.91695804195804 %
# Inverted indexing 79.92132867132867 %
# Inverted indexing 79.9256993006993 %
# Inverted indexing 79.93006993006992 %
# Inverted indexing 79.93444055944056 %
# Inverted indexing 79.93881118881119 %
# Inverted indexing 79.94318181818181 %
# Inverted indexing 79.94755244755245 %
# Inverted indexing 79.95192307692308 %
# Inverted indexing 79.9562937062937 %
# Inverted indexing 79.96066433566433 %
# Inverted indexing 79.96503496503496 %
# Inverted indexing 79.9694055944056 %
# Inverted indexing 79.97377622377623 %
# Inverted indexing 79.97814685314685 %
# Inverted indexing 79.98251748251748 %
# Inverted indexing 79.9868881118881 %
# Inverted indexing 79.99125874125875 %
# Inverted indexing 79.99562937062937 %
# Inverted indexing 80.0 %
# Inverted indexing 80.00437062937063 %
# Inverted indexing 80.00874125874125 %
# Inverted indexing 80.0131118881119 %
# Inverted indexing 80.01748251748252 %
# Inverted indexing 80.02185314685315 %
# Inverted indexing 80.02622377622379 %
# Inverted indexing 80.0305944055944 %
# Inverted indexing 80.03496503496504 %
# Inverted indexing 80.03933566433567 %
# Inverted indexing 80.0437062937063 %
# Inverted indexing 80.04807692307693 %
# Inverted indexing 80.05244755244755 %
# Inverted indexing 80.05681818181817 %
# Inverted indexing 80.06118881118881 %
# Inverted indexing 80.06555944055944 %
# Inverted indexing 80.06993006993007 %
# Inverted indexing 80.07430069930071 %
# Inverted indexing 80.07867132867132 %
# Inverted indexing 80.08304195804196 %
# Inverted indexing 80.08741258741259 %
# Inverted indexing 80.09178321678321 %
# Inverted indexing 80.09615384615385 %
# Inverted indexing 80.10052447552447 %
# Inverted indexing 80.1048951048951 %
# Inverted indexing 80.10926573426573 %
# Inverted indexing 80.11363636363636 %
# Inverted indexing 80.118006993007 %
# Inverted indexing 80.12237762237763 %
# Inverted indexing 80.12674825174825 %
# Inverted indexing 80.13111888111888 %
# Inverted indexing 80.1354895104895 %
# Inverted indexing 80.13986013986015 %
# Inverted indexing 80.14423076923077 %
# Inverted indexing 80.1486013986014 %
# Inverted indexing 80.15297202797203 %
# Inverted indexing 80.15734265734265 %
# Inverted indexing 80.1617132867133 %
# Inverted indexing 80.16608391608392 %
# Inverted indexing 80.17045454545455 %
# Inverted indexing 80.17482517482517 %
# Inverted indexing 80.1791958041958 %
# Inverted indexing 80.18356643356643 %
# Inverted indexing 80.18793706293707 %
# Inverted indexing 80.1923076923077 %
# Inverted indexing 80.19667832167832 %
# Inverted indexing 80.20104895104895 %
# Inverted indexing 80.20541958041957 %
# Inverted indexing 80.20979020979021 %
# Inverted indexing 80.21416083916084 %
# Inverted indexing 80.21853146853147 %
# Inverted indexing 80.2229020979021 %
# Inverted indexing 80.22727272727272 %
# Inverted indexing 80.23164335664336 %
# Inverted indexing 80.23601398601399 %
# Inverted indexing 80.24038461538461 %
# Inverted indexing 80.24475524475524 %
# Inverted indexing 80.24912587412587 %
# Inverted indexing 80.2534965034965 %
# Inverted indexing 80.25786713286713 %
# Inverted indexing 80.26223776223776 %
# Inverted indexing 80.2666083916084 %
# Inverted indexing 80.27097902097901 %
# Inverted indexing 80.27534965034965 %
# Inverted indexing 80.27972027972028 %
# Inverted indexing 80.2840909090909 %
# Inverted indexing 80.28846153846155 %
# Inverted indexing 80.29283216783217 %
# Inverted indexing 80.2972027972028 %
# Inverted indexing 80.30157342657343 %
# Inverted indexing 80.30594405594405 %
# Inverted indexing 80.3103146853147 %
# Inverted indexing 80.31468531468532 %
# Inverted indexing 80.31905594405593 %
# Inverted indexing 80.32342657342657 %
# Inverted indexing 80.3277972027972 %
# Inverted indexing 80.33216783216784 %
# Inverted indexing 80.33653846153847 %
# Inverted indexing 80.3409090909091 %
# Inverted indexing 80.34527972027972 %
# Inverted indexing 80.34965034965035 %
# Inverted indexing 80.35402097902097 %
# Inverted indexing 80.35839160839161 %
# Inverted indexing 80.36276223776224 %
# Inverted indexing 80.36713286713287 %
# Inverted indexing 80.3715034965035 %
# Inverted indexing 80.37587412587412 %
# Inverted indexing 80.38024475524476 %
# Inverted indexing 80.38461538461539 %
# Inverted indexing 80.38898601398601 %
# Inverted indexing 80.39335664335664 %
# Inverted indexing 80.39772727272727 %
# Inverted indexing 80.4020979020979 %
# Inverted indexing 80.40646853146853 %
# Inverted indexing 80.41083916083916 %
# Inverted indexing 80.41520979020979 %
# Inverted indexing 80.41958041958041 %
# Inverted indexing 80.42395104895105 %
# Inverted indexing 80.42832167832168 %
# Inverted indexing 80.4326923076923 %
# Inverted indexing 80.43706293706295 %
# Inverted indexing 80.44143356643356 %
# Inverted indexing 80.4458041958042 %
# Inverted indexing 80.45017482517483 %
# Inverted indexing 80.45454545454545 %
# Inverted indexing 80.4589160839161 %
# Inverted indexing 80.4632867132867 %
# Inverted indexing 80.46765734265733 %
# Inverted indexing 80.47202797202797 %
# Inverted indexing 80.4763986013986 %
# Inverted indexing 80.48076923076923 %
# Inverted indexing 80.48513986013987 %
# Inverted indexing 80.48951048951048 %
# Inverted indexing 80.49388111888112 %
# Inverted indexing 80.49825174825175 %
# Inverted indexing 80.50262237762237 %
# Inverted indexing 80.50699300699301 %
# Inverted indexing 80.51136363636363 %
# Inverted indexing 80.51573426573427 %
# Inverted indexing 80.5201048951049 %
# Inverted indexing 80.52447552447552 %
# Inverted indexing 80.52884615384616 %
# Inverted indexing 80.53321678321679 %
# Inverted indexing 80.53758741258741 %
# Inverted indexing 80.54195804195804 %
# Inverted indexing 80.54632867132867 %
# Inverted indexing 80.5506993006993 %
# Inverted indexing 80.55506993006993 %
# Inverted indexing 80.55944055944056 %
# Inverted indexing 80.56381118881119 %
# Inverted indexing 80.56818181818181 %
# Inverted indexing 80.57255244755245 %
# Inverted indexing 80.57692307692308 %
# Inverted indexing 80.5812937062937 %
# Inverted indexing 80.58566433566433 %
# Inverted indexing 80.59003496503496 %
# Inverted indexing 80.5944055944056 %
# Inverted indexing 80.59877622377623 %
# Inverted indexing 80.60314685314685 %
# Inverted indexing 80.6075174825175 %
# Inverted indexing 80.6118881118881 %
# Inverted indexing 80.61625874125873 %
# Inverted indexing 80.62062937062937 %
# Inverted indexing 80.625 %
# Inverted indexing 80.62937062937064 %
# Inverted indexing 80.63374125874125 %
# Inverted indexing 80.63811188811188 %
# Inverted indexing 80.64248251748252 %
# Inverted indexing 80.64685314685315 %
# Inverted indexing 80.65122377622377 %
# Inverted indexing 80.65559440559441 %
# Inverted indexing 80.65996503496503 %
# Inverted indexing 80.66433566433567 %
# Inverted indexing 80.6687062937063 %
# Inverted indexing 80.67307692307692 %
# Inverted indexing 80.67744755244756 %
# Inverted indexing 80.68181818181817 %
# Inverted indexing 80.68618881118881 %
# Inverted indexing 80.69055944055944 %
# Inverted indexing 80.69493006993007 %
# Inverted indexing 80.69930069930071 %
# Inverted indexing 80.70367132867133 %
# Inverted indexing 80.70804195804196 %
# Inverted indexing 80.71241258741259 %
# Inverted indexing 80.71678321678321 %
# Inverted indexing 80.72115384615385 %
# Inverted indexing 80.72552447552448 %
# Inverted indexing 80.72989510489509 %
# Inverted indexing 80.73426573426573 %
# Inverted indexing 80.73863636363636 %
# Inverted indexing 80.743006993007 %
# Inverted indexing 80.74737762237763 %
# Inverted indexing 80.75174825174825 %
# Inverted indexing 80.75611888111888 %
# Inverted indexing 80.7604895104895 %
# Inverted indexing 80.76486013986013 %
# Inverted indexing 80.76923076923077 %
# Inverted indexing 80.7736013986014 %
# Inverted indexing 80.77797202797203 %
# Inverted indexing 80.78234265734265 %
# Inverted indexing 80.78671328671328 %
# Inverted indexing 80.79108391608392 %
# Inverted indexing 80.79545454545455 %
# Inverted indexing 80.79982517482517 %
# Inverted indexing 80.8041958041958 %
# Inverted indexing 80.80856643356643 %
# Inverted indexing 80.81293706293707 %
# Inverted indexing 80.8173076923077 %
# Inverted indexing 80.82167832167832 %
# Inverted indexing 80.82604895104896 %
# Inverted indexing 80.83041958041957 %
# Inverted indexing 80.83479020979021 %
# Inverted indexing 80.83916083916084 %
# Inverted indexing 80.84353146853147 %
# Inverted indexing 80.84790209790211 %
# Inverted indexing 80.85227272727272 %
# Inverted indexing 80.85664335664336 %
# Inverted indexing 80.86101398601399 %
# Inverted indexing 80.86538461538461 %
# Inverted indexing 80.86975524475525 %
# Inverted indexing 80.87412587412588 %
# Inverted indexing 80.8784965034965 %
# Inverted indexing 80.88286713286713 %
# Inverted indexing 80.88723776223776 %
# Inverted indexing 80.8916083916084 %
# Inverted indexing 80.89597902097903 %
# Inverted indexing 80.90034965034964 %
# Inverted indexing 80.90472027972028 %
# Inverted indexing 80.9090909090909 %
# Inverted indexing 80.91346153846153 %
# Inverted indexing 80.91783216783217 %
# Inverted indexing 80.9222027972028 %
# Inverted indexing 80.92657342657343 %
# Inverted indexing 80.93094405594405 %
# Inverted indexing 80.93531468531468 %
# Inverted indexing 80.93968531468532 %
# Inverted indexing 80.94405594405595 %
# Inverted indexing 80.94842657342657 %
# Inverted indexing 80.9527972027972 %
# Inverted indexing 80.95716783216783 %
# Inverted indexing 80.96153846153847 %
# Inverted indexing 80.9659090909091 %
# Inverted indexing 80.97027972027972 %
# Inverted indexing 80.97465034965035 %
# Inverted indexing 80.97902097902097 %
# Inverted indexing 80.98339160839161 %
# Inverted indexing 80.98776223776224 %
# Inverted indexing 80.99213286713287 %
# Inverted indexing 80.9965034965035 %
# Inverted indexing 81.00087412587412 %
# Inverted indexing 81.00524475524476 %
# Inverted indexing 81.00961538461539 %
# Inverted indexing 81.01398601398601 %
# Inverted indexing 81.01835664335665 %
# Inverted indexing 81.02272727272727 %
# Inverted indexing 81.02709790209789 %
# Inverted indexing 81.03146853146853 %
# Inverted indexing 81.03583916083916 %
# Inverted indexing 81.0402097902098 %
# Inverted indexing 81.04458041958041 %
# Inverted indexing 81.04895104895104 %
# Inverted indexing 81.05332167832168 %
# Inverted indexing 81.0576923076923 %
# Inverted indexing 81.06206293706293 %
# Inverted indexing 81.06643356643357 %
# Inverted indexing 81.07080419580419 %
# Inverted indexing 81.07517482517483 %
# Inverted indexing 81.07954545454545 %
# Inverted indexing 81.08391608391608 %
# Inverted indexing 81.08828671328672 %
# Inverted indexing 81.09265734265733 %
# Inverted indexing 81.09702797202797 %
# Inverted indexing 81.1013986013986 %
# Inverted indexing 81.10576923076923 %
# Inverted indexing 81.11013986013987 %
# Inverted indexing 81.1145104895105 %
# Inverted indexing 81.11888111888112 %
# Inverted indexing 81.12325174825175 %
# Inverted indexing 81.12762237762237 %
# Inverted indexing 81.13199300699301 %
# Inverted indexing 81.13636363636364 %
# Inverted indexing 81.14073426573427 %
# Inverted indexing 81.1451048951049 %
# Inverted indexing 81.14947552447552 %
# Inverted indexing 81.15384615384616 %
# Inverted indexing 81.15821678321679 %
# Inverted indexing 81.16258741258741 %
# Inverted indexing 81.16695804195804 %
# Inverted indexing 81.17132867132867 %
# Inverted indexing 81.1756993006993 %
# Inverted indexing 81.18006993006993 %
# Inverted indexing 81.18444055944056 %
# Inverted indexing 81.1888111888112 %
# Inverted indexing 81.19318181818181 %
# Inverted indexing 81.19755244755244 %
# Inverted indexing 81.20192307692308 %
# Inverted indexing 81.2062937062937 %
# Inverted indexing 81.21066433566433 %
# Inverted indexing 81.21503496503496 %
# Inverted indexing 81.21940559440559 %
# Inverted indexing 81.22377622377623 %
# Inverted indexing 81.22814685314685 %
# Inverted indexing 81.23251748251748 %
# Inverted indexing 81.23688811188812 %
# Inverted indexing 81.24125874125873 %
# Inverted indexing 81.24562937062937 %
# Inverted indexing 81.25 %
# Inverted indexing 81.25437062937063 %
# Inverted indexing 81.25874125874127 %
# Inverted indexing 81.26311188811188 %
# Inverted indexing 81.26748251748252 %
# Inverted indexing 81.27185314685315 %
# Inverted indexing 81.27622377622377 %
# Inverted indexing 81.28059440559441 %
# Inverted indexing 81.28496503496504 %
# Inverted indexing 81.28933566433567 %
# Inverted indexing 81.2937062937063 %
# Inverted indexing 81.29807692307692 %
# Inverted indexing 81.30244755244756 %
# Inverted indexing 81.30681818181819 %
# Inverted indexing 81.3111888111888 %
# Inverted indexing 81.31555944055944 %
# Inverted indexing 81.31993006993007 %
# Inverted indexing 81.3243006993007 %
# Inverted indexing 81.32867132867133 %
# Inverted indexing 81.33304195804196 %
# Inverted indexing 81.33741258741259 %
# Inverted indexing 81.34178321678321 %
# Inverted indexing 81.34615384615384 %
# Inverted indexing 81.35052447552448 %
# Inverted indexing 81.3548951048951 %
# Inverted indexing 81.35926573426573 %
# Inverted indexing 81.36363636363636 %
# Inverted indexing 81.36800699300699 %
# Inverted indexing 81.37237762237763 %
# Inverted indexing 81.37674825174825 %
# Inverted indexing 81.38111888111888 %
# Inverted indexing 81.3854895104895 %
# Inverted indexing 81.38986013986013 %
# Inverted indexing 81.39423076923077 %
# Inverted indexing 81.3986013986014 %
# Inverted indexing 81.40297202797203 %
# Inverted indexing 81.40734265734267 %
# Inverted indexing 81.41171328671328 %
# Inverted indexing 81.41608391608392 %
# Inverted indexing 81.42045454545455 %
# Inverted indexing 81.42482517482517 %
# Inverted indexing 81.42919580419581 %
# Inverted indexing 81.43356643356643 %
# Inverted indexing 81.43793706293707 %
# Inverted indexing 81.4423076923077 %
# Inverted indexing 81.44667832167832 %
# Inverted indexing 81.45104895104896 %
# Inverted indexing 81.45541958041959 %
# Inverted indexing 81.4597902097902 %
# Inverted indexing 81.46416083916084 %
# Inverted indexing 81.46853146853147 %
# Inverted indexing 81.47290209790211 %
# Inverted indexing 81.47727272727273 %
# Inverted indexing 81.48164335664335 %
# Inverted indexing 81.48601398601399 %
# Inverted indexing 81.49038461538461 %
# Inverted indexing 81.49475524475524 %
# Inverted indexing 81.49912587412588 %
# Inverted indexing 81.5034965034965 %
# Inverted indexing 81.50786713286713 %
# Inverted indexing 81.51223776223776 %
# Inverted indexing 81.51660839160839 %
# Inverted indexing 81.52097902097903 %
# Inverted indexing 81.52534965034965 %
# Inverted indexing 81.52972027972028 %
# Inverted indexing 81.5340909090909 %
# Inverted indexing 81.53846153846153 %
# Inverted indexing 81.54283216783217 %
# Inverted indexing 81.5472027972028 %
# Inverted indexing 81.55157342657343 %
# Inverted indexing 81.55594405594405 %
# Inverted indexing 81.56031468531468 %
# Inverted indexing 81.56468531468532 %
# Inverted indexing 81.56905594405595 %
# Inverted indexing 81.57342657342657 %
# Inverted indexing 81.5777972027972 %
# Inverted indexing 81.58216783216783 %
# Inverted indexing 81.58653846153847 %
# Inverted indexing 81.5909090909091 %
# Inverted indexing 81.59527972027972 %
# Inverted indexing 81.59965034965036 %
# Inverted indexing 81.60402097902097 %
# Inverted indexing 81.6083916083916 %
# Inverted indexing 81.61276223776224 %
# Inverted indexing 81.61713286713287 %
# Inverted indexing 81.6215034965035 %
# Inverted indexing 81.62587412587412 %
# Inverted indexing 81.63024475524475 %
# Inverted indexing 81.63461538461539 %
# Inverted indexing 81.63898601398601 %
# Inverted indexing 81.64335664335664 %
# Inverted indexing 81.64772727272728 %
# Inverted indexing 81.65209790209789 %
# Inverted indexing 81.65646853146853 %
# Inverted indexing 81.66083916083916 %
# Inverted indexing 81.66520979020979 %
# Inverted indexing 81.66958041958043 %
# Inverted indexing 81.67395104895104 %
# Inverted indexing 81.67832167832168 %
# Inverted indexing 81.6826923076923 %
# Inverted indexing 81.68706293706293 %
# Inverted indexing 81.69143356643357 %
# Inverted indexing 81.6958041958042 %
# Inverted indexing 81.70017482517483 %
# Inverted indexing 81.70454545454545 %
# Inverted indexing 81.70891608391608 %
# Inverted indexing 81.71328671328672 %
# Inverted indexing 81.71765734265735 %
# Inverted indexing 81.72202797202797 %
# Inverted indexing 81.7263986013986 %
# Inverted indexing 81.73076923076923 %
# Inverted indexing 81.73513986013987 %
# Inverted indexing 81.7395104895105 %
# Inverted indexing 81.74388111888112 %
# Inverted indexing 81.74825174825175 %
# Inverted indexing 81.75262237762237 %
# Inverted indexing 81.756993006993 %
# Inverted indexing 81.76136363636364 %
# Inverted indexing 81.76573426573427 %
# Inverted indexing 81.77010489510491 %
# Inverted indexing 81.77447552447552 %
# Inverted indexing 81.77884615384615 %
# Inverted indexing 81.78321678321679 %
# Inverted indexing 81.78758741258741 %
# Inverted indexing 81.79195804195804 %
# Inverted indexing 81.79632867132867 %
# Inverted indexing 81.80069930069929 %
# Inverted indexing 81.80506993006993 %
# Inverted indexing 81.80944055944056 %
# Inverted indexing 81.81381118881119 %
# Inverted indexing 81.81818181818183 %
# Inverted indexing 81.82255244755244 %
# Inverted indexing 81.82692307692308 %
# Inverted indexing 81.8312937062937 %
# Inverted indexing 81.83566433566433 %
# Inverted indexing 81.84003496503497 %
# Inverted indexing 81.84440559440559 %
# Inverted indexing 81.84877622377623 %
# Inverted indexing 81.85314685314685 %
# Inverted indexing 81.85751748251748 %
# Inverted indexing 81.86188811188812 %
# Inverted indexing 81.86625874125875 %
# Inverted indexing 81.87062937062936 %
# Inverted indexing 81.875 %
# Inverted indexing 81.87937062937063 %
# Inverted indexing 81.88374125874127 %
# Inverted indexing 81.8881118881119 %
# Inverted indexing 81.8924825174825 %
# Inverted indexing 81.89685314685315 %
# Inverted indexing 81.90122377622377 %
# Inverted indexing 81.9055944055944 %
# Inverted indexing 81.90996503496504 %
# Inverted indexing 81.91433566433567 %
# Inverted indexing 81.9187062937063 %
# Inverted indexing 81.92307692307692 %
# Inverted indexing 81.92744755244755 %
# Inverted indexing 81.93181818181819 %
# Inverted indexing 81.93618881118881 %
# Inverted indexing 81.94055944055944 %
# Inverted indexing 81.94493006993007 %
# Inverted indexing 81.9493006993007 %
# Inverted indexing 81.95367132867133 %
# Inverted indexing 81.95804195804196 %
# Inverted indexing 81.96241258741259 %
# Inverted indexing 81.96678321678321 %
# Inverted indexing 81.97115384615384 %
# Inverted indexing 81.97552447552448 %
# Inverted indexing 81.9798951048951 %
# Inverted indexing 81.98426573426573 %
# Inverted indexing 81.98863636363637 %
# Inverted indexing 81.99300699300699 %
# Inverted indexing 81.99737762237763 %
# Inverted indexing 82.00174825174825 %
# Inverted indexing 82.00611888111888 %
# Inverted indexing 82.01048951048952 %
# Inverted indexing 82.01486013986013 %
# Inverted indexing 82.01923076923077 %
# Inverted indexing 82.0236013986014 %
# Inverted indexing 82.02797202797203 %
# Inverted indexing 82.03234265734267 %
# Inverted indexing 82.0367132867133 %
# Inverted indexing 82.0410839160839 %
# Inverted indexing 82.04545454545455 %
# Inverted indexing 82.04982517482517 %
# Inverted indexing 82.0541958041958 %
# Inverted indexing 82.05856643356644 %
# Inverted indexing 82.06293706293705 %
# Inverted indexing 82.0673076923077 %
# Inverted indexing 82.07167832167832 %
# Inverted indexing 82.07604895104895 %
# Inverted indexing 82.08041958041959 %
# Inverted indexing 82.08479020979021 %
# Inverted indexing 82.08916083916084 %
# Inverted indexing 82.09353146853147 %
# Inverted indexing 82.0979020979021 %
# Inverted indexing 82.10227272727273 %
# Inverted indexing 82.10664335664336 %
# Inverted indexing 82.11101398601399 %
# Inverted indexing 82.11538461538461 %
# Inverted indexing 82.11975524475524 %
# Inverted indexing 82.12412587412588 %
# Inverted indexing 82.1284965034965 %
# Inverted indexing 82.13286713286713 %
# Inverted indexing 82.13723776223776 %
# Inverted indexing 82.14160839160839 %
# Inverted indexing 82.14597902097903 %
# Inverted indexing 82.15034965034965 %
# Inverted indexing 82.15472027972028 %
# Inverted indexing 82.1590909090909 %
# Inverted indexing 82.16346153846153 %
# Inverted indexing 82.16783216783216 %
# Inverted indexing 82.1722027972028 %
# Inverted indexing 82.17657342657343 %
# Inverted indexing 82.18094405594407 %
# Inverted indexing 82.18531468531468 %
# Inverted indexing 82.1896853146853 %
# Inverted indexing 82.19405594405595 %
# Inverted indexing 82.19842657342657 %
# Inverted indexing 82.2027972027972 %
# Inverted indexing 82.20716783216783 %
# Inverted indexing 82.21153846153845 %
# Inverted indexing 82.2159090909091 %
# Inverted indexing 82.22027972027972 %
# Inverted indexing 82.22465034965035 %
# Inverted indexing 82.22902097902099 %
# Inverted indexing 82.2333916083916 %
# Inverted indexing 82.23776223776224 %
# Inverted indexing 82.24213286713287 %
# Inverted indexing 82.2465034965035 %
# Inverted indexing 82.25087412587413 %
# Inverted indexing 82.25524475524476 %
# Inverted indexing 82.25961538461539 %
# Inverted indexing 82.26398601398601 %
# Inverted indexing 82.26835664335664 %
# Inverted indexing 82.27272727272728 %
# Inverted indexing 82.2770979020979 %
# Inverted indexing 82.28146853146853 %
# Inverted indexing 82.28583916083916 %
# Inverted indexing 82.29020979020979 %
# Inverted indexing 82.29458041958043 %
# Inverted indexing 82.29895104895105 %
# Inverted indexing 82.30332167832168 %
# Inverted indexing 82.3076923076923 %
# Inverted indexing 82.31206293706293 %
# Inverted indexing 82.31643356643357 %
# Inverted indexing 82.3208041958042 %
# Inverted indexing 82.32517482517483 %
# Inverted indexing 82.32954545454545 %
# Inverted indexing 82.33391608391608 %
# Inverted indexing 82.3382867132867 %
# Inverted indexing 82.34265734265735 %
# Inverted indexing 82.34702797202797 %
# Inverted indexing 82.3513986013986 %
# Inverted indexing 82.35576923076923 %
# Inverted indexing 82.36013986013985 %
# Inverted indexing 82.3645104895105 %
# Inverted indexing 82.36888111888112 %
# Inverted indexing 82.37325174825175 %
# Inverted indexing 82.37762237762237 %
# Inverted indexing 82.381993006993 %
# Inverted indexing 82.38636363636364 %
# Inverted indexing 82.39073426573427 %
# Inverted indexing 82.3951048951049 %
# Inverted indexing 82.39947552447553 %
# Inverted indexing 82.40384615384615 %
# Inverted indexing 82.40821678321679 %
# Inverted indexing 82.41258741258741 %
# Inverted indexing 82.41695804195804 %
# Inverted indexing 82.42132867132868 %
# Inverted indexing 82.42569930069929 %
# Inverted indexing 82.43006993006993 %
# Inverted indexing 82.43444055944056 %
# Inverted indexing 82.43881118881119 %
# Inverted indexing 82.44318181818183 %
# Inverted indexing 82.44755244755245 %
# Inverted indexing 82.45192307692307 %
# Inverted indexing 82.4562937062937 %
# Inverted indexing 82.46066433566433 %
# Inverted indexing 82.46503496503496 %
# Inverted indexing 82.4694055944056 %
# Inverted indexing 82.47377622377621 %
# Inverted indexing 82.47814685314685 %
# Inverted indexing 82.48251748251748 %
# Inverted indexing 82.4868881118881 %
# Inverted indexing 82.49125874125875 %
# Inverted indexing 82.49562937062937 %
# Inverted indexing 82.5 %
# Inverted indexing 82.50437062937063 %
# Inverted indexing 82.50874125874125 %
# Inverted indexing 82.5131118881119 %
# Inverted indexing 82.51748251748252 %
# Inverted indexing 82.52185314685315 %
# Inverted indexing 82.52622377622377 %
# Inverted indexing 82.5305944055944 %
# Inverted indexing 82.53496503496504 %
# Inverted indexing 82.53933566433567 %
# Inverted indexing 82.5437062937063 %
# Inverted indexing 82.54807692307692 %
# Inverted indexing 82.55244755244755 %
# Inverted indexing 82.55681818181819 %
# Inverted indexing 82.56118881118881 %
# Inverted indexing 82.56555944055944 %
# Inverted indexing 82.56993006993008 %
# Inverted indexing 82.5743006993007 %
# Inverted indexing 82.57867132867133 %
# Inverted indexing 82.58304195804196 %
# Inverted indexing 82.58741258741259 %
# Inverted indexing 82.59178321678323 %
# Inverted indexing 82.59615384615384 %
# Inverted indexing 82.60052447552447 %
# Inverted indexing 82.6048951048951 %
# Inverted indexing 82.60926573426573 %
# Inverted indexing 82.61363636363637 %
# Inverted indexing 82.618006993007 %
# Inverted indexing 82.62237762237761 %
# Inverted indexing 82.62674825174825 %
# Inverted indexing 82.63111888111888 %
# Inverted indexing 82.6354895104895 %
# Inverted indexing 82.63986013986015 %
# Inverted indexing 82.64423076923076 %
# Inverted indexing 82.6486013986014 %
# Inverted indexing 82.65297202797203 %
# Inverted indexing 82.65734265734265 %
# Inverted indexing 82.6617132867133 %
# Inverted indexing 82.66608391608392 %
# Inverted indexing 82.67045454545455 %
# Inverted indexing 82.67482517482517 %
# Inverted indexing 82.6791958041958 %
# Inverted indexing 82.68356643356644 %
# Inverted indexing 82.68793706293707 %
# Inverted indexing 82.6923076923077 %
# Inverted indexing 82.69667832167832 %
# Inverted indexing 82.70104895104895 %
# Inverted indexing 82.70541958041959 %
# Inverted indexing 82.70979020979021 %
# Inverted indexing 82.71416083916084 %
# Inverted indexing 82.71853146853147 %
# Inverted indexing 82.7229020979021 %
# Inverted indexing 82.72727272727273 %
# Inverted indexing 82.73164335664336 %
# Inverted indexing 82.73601398601399 %
# Inverted indexing 82.74038461538461 %
# Inverted indexing 82.74475524475524 %
# Inverted indexing 82.74912587412587 %
# Inverted indexing 82.7534965034965 %
# Inverted indexing 82.75786713286713 %
# Inverted indexing 82.76223776223776 %
# Inverted indexing 82.76660839160839 %
# Inverted indexing 82.77097902097901 %
# Inverted indexing 82.77534965034965 %
# Inverted indexing 82.77972027972028 %
# Inverted indexing 82.7840909090909 %
# Inverted indexing 82.78846153846153 %
# Inverted indexing 82.79283216783216 %
# Inverted indexing 82.7972027972028 %
# Inverted indexing 82.80157342657343 %
# Inverted indexing 82.80594405594405 %
# Inverted indexing 82.8103146853147 %
# Inverted indexing 82.8146853146853 %
# Inverted indexing 82.81905594405595 %
# Inverted indexing 82.82342657342657 %
# Inverted indexing 82.8277972027972 %
# Inverted indexing 82.83216783216784 %
# Inverted indexing 82.83653846153847 %
# Inverted indexing 82.8409090909091 %
# Inverted indexing 82.84527972027972 %
# Inverted indexing 82.84965034965035 %
# Inverted indexing 82.85402097902099 %
# Inverted indexing 82.85839160839161 %
# Inverted indexing 82.86276223776224 %
# Inverted indexing 82.86713286713287 %
# Inverted indexing 82.8715034965035 %
# Inverted indexing 82.87587412587413 %
# Inverted indexing 82.88024475524476 %
# Inverted indexing 82.88461538461539 %
# Inverted indexing 82.88898601398601 %
# Inverted indexing 82.89335664335664 %
# Inverted indexing 82.89772727272727 %
# Inverted indexing 82.9020979020979 %
# Inverted indexing 82.90646853146853 %
# Inverted indexing 82.91083916083916 %
# Inverted indexing 82.91520979020979 %
# Inverted indexing 82.91958041958041 %
# Inverted indexing 82.92395104895105 %
# Inverted indexing 82.92832167832168 %
# Inverted indexing 82.9326923076923 %
# Inverted indexing 82.93706293706293 %
# Inverted indexing 82.94143356643356 %
# Inverted indexing 82.9458041958042 %
# Inverted indexing 82.95017482517483 %
# Inverted indexing 82.95454545454545 %
# Inverted indexing 82.95891608391608 %
# Inverted indexing 82.9632867132867 %
# Inverted indexing 82.96765734265735 %
# Inverted indexing 82.97202797202797 %
# Inverted indexing 82.9763986013986 %
# Inverted indexing 82.98076923076924 %
# Inverted indexing 82.98513986013985 %
# Inverted indexing 82.9895104895105 %
# Inverted indexing 82.99388111888112 %
# Inverted indexing 82.99825174825175 %
# Inverted indexing 83.00262237762239 %
# Inverted indexing 83.006993006993 %
# Inverted indexing 83.01136363636363 %
# Inverted indexing 83.01573426573427 %
# Inverted indexing 83.0201048951049 %
# Inverted indexing 83.02447552447553 %
# Inverted indexing 83.02884615384616 %
# Inverted indexing 83.03321678321677 %
# Inverted indexing 83.03758741258741 %
# Inverted indexing 83.04195804195804 %
# Inverted indexing 83.04632867132867 %
# Inverted indexing 83.0506993006993 %
# Inverted indexing 83.05506993006992 %
# Inverted indexing 83.05944055944056 %
# Inverted indexing 83.06381118881119 %
# Inverted indexing 83.06818181818181 %
# Inverted indexing 83.07255244755245 %
# Inverted indexing 83.07692307692308 %
# Inverted indexing 83.0812937062937 %
# Inverted indexing 83.08566433566433 %
# Inverted indexing 83.09003496503496 %
# Inverted indexing 83.0944055944056 %
# Inverted indexing 83.09877622377623 %
# Inverted indexing 83.10314685314685 %
# Inverted indexing 83.10751748251748 %
# Inverted indexing 83.1118881118881 %
# Inverted indexing 83.11625874125875 %
# Inverted indexing 83.12062937062937 %
# Inverted indexing 83.125 %
# Inverted indexing 83.12937062937063 %
# Inverted indexing 83.13374125874125 %
# Inverted indexing 83.1381118881119 %
# Inverted indexing 83.14248251748252 %
# Inverted indexing 83.14685314685315 %
# Inverted indexing 83.15122377622379 %
# Inverted indexing 83.1555944055944 %
# Inverted indexing 83.15996503496504 %
# Inverted indexing 83.16433566433567 %
# Inverted indexing 83.1687062937063 %
# Inverted indexing 83.17307692307693 %
# Inverted indexing 83.17744755244755 %
# Inverted indexing 83.18181818181817 %
# Inverted indexing 83.18618881118881 %
# Inverted indexing 83.19055944055944 %
# Inverted indexing 83.19493006993007 %
# Inverted indexing 83.19930069930071 %
# Inverted indexing 83.20367132867132 %
# Inverted indexing 83.20804195804196 %
# Inverted indexing 83.21241258741259 %
# Inverted indexing 83.21678321678321 %
# Inverted indexing 83.22115384615385 %
# Inverted indexing 83.22552447552447 %
# Inverted indexing 83.2298951048951 %
# Inverted indexing 83.23426573426573 %
# Inverted indexing 83.23863636363636 %
# Inverted indexing 83.243006993007 %
# Inverted indexing 83.24737762237763 %
# Inverted indexing 83.25174825174825 %
# Inverted indexing 83.25611888111888 %
# Inverted indexing 83.2604895104895 %
# Inverted indexing 83.26486013986015 %
# Inverted indexing 83.26923076923077 %
# Inverted indexing 83.2736013986014 %
# Inverted indexing 83.27797202797203 %
# Inverted indexing 83.28234265734265 %
# Inverted indexing 83.2867132867133 %
# Inverted indexing 83.29108391608392 %
# Inverted indexing 83.29545454545455 %
# Inverted indexing 83.29982517482517 %
# Inverted indexing 83.3041958041958 %
# Inverted indexing 83.30856643356643 %
# Inverted indexing 83.31293706293707 %
# Inverted indexing 83.3173076923077 %
# Inverted indexing 83.32167832167832 %
# Inverted indexing 83.32604895104895 %
# Inverted indexing 83.33041958041957 %
# Inverted indexing 83.33479020979021 %
# Inverted indexing 83.33916083916084 %
# Inverted indexing 83.34353146853147 %
# Inverted indexing 83.3479020979021 %
# Inverted indexing 83.35227272727272 %
# Inverted indexing 83.35664335664336 %
# Inverted indexing 83.36101398601399 %
# Inverted indexing 83.36538461538461 %
# Inverted indexing 83.36975524475524 %
# Inverted indexing 83.37412587412587 %
# Inverted indexing 83.3784965034965 %
# Inverted indexing 83.38286713286713 %
# Inverted indexing 83.38723776223776 %
# Inverted indexing 83.3916083916084 %
# Inverted indexing 83.39597902097901 %
# Inverted indexing 83.40034965034965 %
# Inverted indexing 83.40472027972028 %
# Inverted indexing 83.4090909090909 %
# Inverted indexing 83.41346153846155 %
# Inverted indexing 83.41783216783217 %
# Inverted indexing 83.4222027972028 %
# Inverted indexing 83.42657342657343 %
# Inverted indexing 83.43094405594405 %
# Inverted indexing 83.4353146853147 %
# Inverted indexing 83.43968531468532 %
# Inverted indexing 83.44405594405593 %
# Inverted indexing 83.44842657342657 %
# Inverted indexing 83.4527972027972 %
# Inverted indexing 83.45716783216784 %
# Inverted indexing 83.46153846153847 %
# Inverted indexing 83.4659090909091 %
# Inverted indexing 83.47027972027972 %
# Inverted indexing 83.47465034965035 %
# Inverted indexing 83.47902097902097 %
# Inverted indexing 83.48339160839161 %
# Inverted indexing 83.48776223776224 %
# Inverted indexing 83.49213286713287 %
# Inverted indexing 83.4965034965035 %
# Inverted indexing 83.50087412587412 %
# Inverted indexing 83.50524475524476 %
# Inverted indexing 83.50961538461539 %
# Inverted indexing 83.51398601398601 %
# Inverted indexing 83.51835664335664 %
# Inverted indexing 83.52272727272727 %
# Inverted indexing 83.5270979020979 %
# Inverted indexing 83.53146853146853 %
# Inverted indexing 83.53583916083916 %
# Inverted indexing 83.54020979020979 %
# Inverted indexing 83.54458041958041 %
# Inverted indexing 83.54895104895105 %
# Inverted indexing 83.55332167832168 %
# Inverted indexing 83.5576923076923 %
# Inverted indexing 83.56206293706295 %
# Inverted indexing 83.56643356643356 %
# Inverted indexing 83.5708041958042 %
# Inverted indexing 83.57517482517483 %
# Inverted indexing 83.57954545454545 %
# Inverted indexing 83.5839160839161 %
# Inverted indexing 83.5882867132867 %
# Inverted indexing 83.59265734265733 %
# Inverted indexing 83.59702797202797 %
# Inverted indexing 83.6013986013986 %
# Inverted indexing 83.60576923076923 %
# Inverted indexing 83.61013986013987 %
# Inverted indexing 83.61451048951048 %
# Inverted indexing 83.61888111888112 %
# Inverted indexing 83.62325174825175 %
# Inverted indexing 83.62762237762237 %
# Inverted indexing 83.63199300699301 %
# Inverted indexing 83.63636363636363 %
# Inverted indexing 83.64073426573427 %
# Inverted indexing 83.6451048951049 %
# Inverted indexing 83.64947552447552 %
# Inverted indexing 83.65384615384616 %
# Inverted indexing 83.65821678321679 %
# Inverted indexing 83.66258741258741 %
# Inverted indexing 83.66695804195804 %
# Inverted indexing 83.67132867132867 %
# Inverted indexing 83.6756993006993 %
# Inverted indexing 83.68006993006993 %
# Inverted indexing 83.68444055944056 %
# Inverted indexing 83.68881118881119 %
# Inverted indexing 83.69318181818181 %
# Inverted indexing 83.69755244755245 %
# Inverted indexing 83.70192307692308 %
# ...
# Inverted indexing 98.15122377622377 %
# Inverted indexing 98.1555944055944 %
# Inverted indexing 98.15996503496504 %
# Inverted indexing 98.16433566433567 %
# Inverted indexing 98.1687062937063 %
# Inverted indexing 98.17307692307692 %
# Inverted indexing 98.17744755244755 %
# Inverted indexing 98.18181818181819 %
# Inverted indexing 98.18618881118881 %
# Inverted indexing 98.19055944055944 %
# Inverted indexing 98.19493006993008 %
# Inverted indexing 98.1993006993007 %
# Inverted indexing 98.20367132867133 %
# Inverted indexing 98.20804195804196 %
# Inverted indexing 98.21241258741259 %
# Inverted indexing 98.21678321678323 %
# Inverted indexing 98.22115384615384 %
# Inverted indexing 98.22552447552447 %
# Inverted indexing 98.2298951048951 %
# Inverted indexing 98.23426573426573 %
# Inverted indexing 98.23863636363637 %
# Inverted indexing 98.243006993007 %
# Inverted indexing 98.24737762237761 %
# Inverted indexing 98.25174825174825 %
# Inverted indexing 98.25611888111888 %
# Inverted indexing 98.2604895104895 %
# Inverted indexing 98.26486013986015 %
# Inverted indexing 98.26923076923076 %
# Inverted indexing 98.2736013986014 %
# Inverted indexing 98.27797202797203 %
# Inverted indexing 98.28234265734265 %
# Inverted indexing 98.2867132867133 %
# Inverted indexing 98.29108391608392 %
# Inverted indexing 98.29545454545455 %
# Inverted indexing 98.29982517482517 %
# Inverted indexing 98.3041958041958 %
# Inverted indexing 98.30856643356644 %
# Inverted indexing 98.31293706293707 %
# Inverted indexing 98.3173076923077 %
# Inverted indexing 98.32167832167832 %
# Inverted indexing 98.32604895104895 %
# Inverted indexing 98.33041958041959 %
# Inverted indexing 98.33479020979021 %
# Inverted indexing 98.33916083916084 %
# Inverted indexing 98.34353146853147 %
# Inverted indexing 98.3479020979021 %
# Inverted indexing 98.35227272727273 %
# Inverted indexing 98.35664335664336 %
# Inverted indexing 98.36101398601399 %
# Inverted indexing 98.36538461538461 %
# Inverted indexing 98.36975524475524 %
# Inverted indexing 98.37412587412587 %
# Inverted indexing 98.3784965034965 %
# Inverted indexing 98.38286713286713 %
# Inverted indexing 98.38723776223776 %
# Inverted indexing 98.39160839160839 %
# Inverted indexing 98.39597902097901 %
# Inverted indexing 98.40034965034965 %
# Inverted indexing 98.40472027972028 %
# Inverted indexing 98.4090909090909 %
# Inverted indexing 98.41346153846153 %
# Inverted indexing 98.41783216783216 %
# Inverted indexing 98.4222027972028 %
# Inverted indexing 98.42657342657343 %
# Inverted indexing 98.43094405594405 %
# Inverted indexing 98.4353146853147 %
# Inverted indexing 98.4396853146853 %
# Inverted indexing 98.44405594405595 %
# Inverted indexing 98.44842657342657 %
# Inverted indexing 98.4527972027972 %
# Inverted indexing 98.45716783216784 %
# Inverted indexing 98.46153846153847 %
# Inverted indexing 98.4659090909091 %
# Inverted indexing 98.47027972027972 %
# Inverted indexing 98.47465034965035 %
# Inverted indexing 98.47902097902099 %
# Inverted indexing 98.48339160839161 %
# Inverted indexing 98.48776223776224 %
# Inverted indexing 98.49213286713287 %
# Inverted indexing 98.4965034965035 %
# Inverted indexing 98.50087412587413 %
# Inverted indexing 98.50524475524476 %
# Inverted indexing 98.50961538461539 %
# Inverted indexing 98.51398601398601 %
# Inverted indexing 98.51835664335664 %
# Inverted indexing 98.52272727272727 %
# Inverted indexing 98.5270979020979 %
# Inverted indexing 98.53146853146853 %
# Inverted indexing 98.53583916083916 %
# Inverted indexing 98.54020979020979 %
# Inverted indexing 98.54458041958041 %
# Inverted indexing 98.54895104895105 %
# Inverted indexing 98.55332167832168 %
# Inverted indexing 98.5576923076923 %
# Inverted indexing 98.56206293706293 %
# Inverted indexing 98.56643356643356 %
# Inverted indexing 98.5708041958042 %
# Inverted indexing 98.57517482517483 %
# Inverted indexing 98.57954545454545 %
# Inverted indexing 98.58391608391608 %
# Inverted indexing 98.5882867132867 %
# Inverted indexing 98.59265734265735 %
# Inverted indexing 98.59702797202797 %
# Inverted indexing 98.6013986013986 %
# Inverted indexing 98.60576923076924 %
# Inverted indexing 98.61013986013985 %
# Inverted indexing 98.6145104895105 %
# Inverted indexing 98.61888111888112 %
# Inverted indexing 98.62325174825175 %
# Inverted indexing 98.62762237762239 %
# Inverted indexing 98.631993006993 %
# Inverted indexing 98.63636363636363 %
# Inverted indexing 98.64073426573427 %
# Inverted indexing 98.6451048951049 %
# Inverted indexing 98.64947552447553 %
# Inverted indexing 98.65384615384616 %
# Inverted indexing 98.65821678321677 %
# Inverted indexing 98.66258741258741 %
# Inverted indexing 98.66695804195804 %
# Inverted indexing 98.67132867132867 %
# Inverted indexing 98.6756993006993 %
# Inverted indexing 98.68006993006992 %
# Inverted indexing 98.68444055944056 %
# Inverted indexing 98.68881118881119 %
# Inverted indexing 98.69318181818181 %
# Inverted indexing 98.69755244755245 %
# Inverted indexing 98.70192307692308 %
# Inverted indexing 98.7062937062937 %
# Inverted indexing 98.71066433566433 %
# Inverted indexing 98.71503496503496 %
# Inverted indexing 98.7194055944056 %
# Inverted indexing 98.72377622377623 %
# Inverted indexing 98.72814685314685 %
# Inverted indexing 98.73251748251748 %
# Inverted indexing 98.7368881118881 %
# Inverted indexing 98.74125874125875 %
# Inverted indexing 98.74562937062937 %
# Inverted indexing 98.75 %
# Inverted indexing 98.75437062937063 %
# Inverted indexing 98.75874125874125 %
# Inverted indexing 98.7631118881119 %
# Inverted indexing 98.76748251748252 %
# Inverted indexing 98.77185314685315 %
# Inverted indexing 98.77622377622379 %
# Inverted indexing 98.7805944055944 %
# Inverted indexing 98.78496503496504 %
# Inverted indexing 98.78933566433567 %
# Inverted indexing 98.7937062937063 %
# Inverted indexing 98.79807692307693 %
# Inverted indexing 98.80244755244755 %
# Inverted indexing 98.80681818181817 %
# Inverted indexing 98.81118881118881 %
# Inverted indexing 98.81555944055944 %
# Inverted indexing 98.81993006993007 %
# Inverted indexing 98.82430069930071 %
# Inverted indexing 98.82867132867132 %
# Inverted indexing 98.83304195804196 %
# Inverted indexing 98.83741258741259 %
# Inverted indexing 98.84178321678321 %
# Inverted indexing 98.84615384615385 %
# Inverted indexing 98.85052447552447 %
# Inverted indexing 98.8548951048951 %
# Inverted indexing 98.85926573426573 %
# Inverted indexing 98.86363636363636 %
# Inverted indexing 98.868006993007 %
# Inverted indexing 98.87237762237763 %
# Inverted indexing 98.87674825174825 %
# Inverted indexing 98.88111888111888 %
# Inverted indexing 98.8854895104895 %
# Inverted indexing 98.88986013986015 %
# Inverted indexing 98.89423076923077 %
# Inverted indexing 98.8986013986014 %
# Inverted indexing 98.90297202797203 %
# Inverted indexing 98.90734265734265 %
# Inverted indexing 98.9117132867133 %
# Inverted indexing 98.91608391608392 %
# Inverted indexing 98.92045454545455 %
# Inverted indexing 98.92482517482517 %
# Inverted indexing 98.9291958041958 %
# Inverted indexing 98.93356643356643 %
# Inverted indexing 98.93793706293707 %
# Inverted indexing 98.9423076923077 %
# Inverted indexing 98.94667832167832 %
# Inverted indexing 98.95104895104895 %
# Inverted indexing 98.95541958041957 %
# Inverted indexing 98.95979020979021 %
# Inverted indexing 98.96416083916084 %
# Inverted indexing 98.96853146853147 %
# Inverted indexing 98.9729020979021 %
# Inverted indexing 98.97727272727272 %
# Inverted indexing 98.98164335664336 %
# Inverted indexing 98.98601398601399 %
# Inverted indexing 98.99038461538461 %
# Inverted indexing 98.99475524475524 %
# Inverted indexing 98.99912587412587 %
# Inverted indexing 99.0034965034965 %
# Inverted indexing 99.00786713286713 %
# Inverted indexing 99.01223776223776 %
# Inverted indexing 99.0166083916084 %
# Inverted indexing 99.02097902097901 %
# Inverted indexing 99.02534965034965 %
# Inverted indexing 99.02972027972028 %
# Inverted indexing 99.0340909090909 %
# Inverted indexing 99.03846153846155 %
# Inverted indexing 99.04283216783217 %
# Inverted indexing 99.0472027972028 %
# Inverted indexing 99.05157342657343 %
# Inverted indexing 99.05594405594405 %
# Inverted indexing 99.0603146853147 %
# Inverted indexing 99.06468531468532 %
# Inverted indexing 99.06905594405593 %
# Inverted indexing 99.07342657342657 %
# Inverted indexing 99.0777972027972 %
# Inverted indexing 99.08216783216784 %
# Inverted indexing 99.08653846153847 %
# Inverted indexing 99.0909090909091 %
# Inverted indexing 99.09527972027972 %
# Inverted indexing 99.09965034965035 %
# Inverted indexing 99.10402097902097 %
# Inverted indexing 99.10839160839161 %
# Inverted indexing 99.11276223776224 %
# Inverted indexing 99.11713286713287 %
# Inverted indexing 99.1215034965035 %
# Inverted indexing 99.12587412587412 %
# Inverted indexing 99.13024475524476 %
# Inverted indexing 99.13461538461539 %
# Inverted indexing 99.13898601398601 %
# Inverted indexing 99.14335664335664 %
# Inverted indexing 99.14772727272727 %
# Inverted indexing 99.1520979020979 %
# Inverted indexing 99.15646853146853 %
# Inverted indexing 99.16083916083916 %
# Inverted indexing 99.16520979020979 %
# Inverted indexing 99.16958041958041 %
# Inverted indexing 99.17395104895105 %
# Inverted indexing 99.17832167832168 %
# Inverted indexing 99.1826923076923 %
# Inverted indexing 99.18706293706295 %
# Inverted indexing 99.19143356643356 %
# Inverted indexing 99.1958041958042 %
# Inverted indexing 99.20017482517483 %
# Inverted indexing 99.20454545454545 %
# Inverted indexing 99.2089160839161 %
# Inverted indexing 99.2132867132867 %
# Inverted indexing 99.21765734265733 %
# Inverted indexing 99.22202797202797 %
# Inverted indexing 99.2263986013986 %
# Inverted indexing 99.23076923076923 %
# Inverted indexing 99.23513986013987 %
# Inverted indexing 99.23951048951048 %
# Inverted indexing 99.24388111888112 %
# Inverted indexing 99.24825174825175 %
# Inverted indexing 99.25262237762237 %
# Inverted indexing 99.25699300699301 %
# Inverted indexing 99.26136363636363 %
# Inverted indexing 99.26573426573427 %
# Inverted indexing 99.2701048951049 %
# Inverted indexing 99.27447552447552 %
# Inverted indexing 99.27884615384616 %
# Inverted indexing 99.28321678321679 %
# Inverted indexing 99.28758741258741 %
# Inverted indexing 99.29195804195804 %
# Inverted indexing 99.29632867132867 %
# Inverted indexing 99.3006993006993 %
# Inverted indexing 99.30506993006993 %
# Inverted indexing 99.30944055944056 %
# Inverted indexing 99.31381118881119 %
# Inverted indexing 99.31818181818181 %
# Inverted indexing 99.32255244755245 %
# Inverted indexing 99.32692307692308 %
# Inverted indexing 99.3312937062937 %
# Inverted indexing 99.33566433566433 %
# Inverted indexing 99.34003496503496 %
# Inverted indexing 99.3444055944056 %
# Inverted indexing 99.34877622377623 %
# Inverted indexing 99.35314685314685 %
# Inverted indexing 99.3575174825175 %
# Inverted indexing 99.3618881118881 %
# Inverted indexing 99.36625874125873 %
# Inverted indexing 99.37062937062937 %
# Inverted indexing 99.375 %
# Inverted indexing 99.37937062937064 %
# Inverted indexing 99.38374125874125 %
# Inverted indexing 99.38811188811188 %
# Inverted indexing 99.39248251748252 %
# Inverted indexing 99.39685314685315 %
# Inverted indexing 99.40122377622377 %
# Inverted indexing 99.40559440559441 %
# Inverted indexing 99.40996503496503 %
# Inverted indexing 99.41433566433567 %
# Inverted indexing 99.4187062937063 %
# Inverted indexing 99.42307692307692 %
# Inverted indexing 99.42744755244756 %
# Inverted indexing 99.43181818181817 %
# Inverted indexing 99.43618881118881 %
# Inverted indexing 99.44055944055944 %
# Inverted indexing 99.44493006993007 %
# Inverted indexing 99.44930069930071 %
# Inverted indexing 99.45367132867133 %
# Inverted indexing 99.45804195804196 %
# Inverted indexing 99.46241258741259 %
# Inverted indexing 99.46678321678321 %
# Inverted indexing 99.47115384615385 %
# Inverted indexing 99.47552447552448 %
# Inverted indexing 99.47989510489509 %
# Inverted indexing 99.48426573426573 %
# Inverted indexing 99.48863636363636 %
# Inverted indexing 99.493006993007 %
# Inverted indexing 99.49737762237763 %
# Inverted indexing 99.50174825174825 %
# Inverted indexing 99.50611888111888 %
# Inverted indexing 99.5104895104895 %
# Inverted indexing 99.51486013986013 %
# Inverted indexing 99.51923076923077 %
# Inverted indexing 99.5236013986014 %
# Inverted indexing 99.52797202797203 %
# Inverted indexing 99.53234265734265 %
# Inverted indexing 99.53671328671328 %
# Inverted indexing 99.54108391608392 %
# Inverted indexing 99.54545454545455 %
# Inverted indexing 99.54982517482517 %
# Inverted indexing 99.5541958041958 %
# Inverted indexing 99.55856643356643 %
# Inverted indexing 99.56293706293707 %
# Inverted indexing 99.5673076923077 %
# Inverted indexing 99.57167832167832 %
# Inverted indexing 99.57604895104896 %
# Inverted indexing 99.58041958041957 %
# Inverted indexing 99.58479020979021 %
# Inverted indexing 99.58916083916084 %
# Inverted indexing 99.59353146853147 %
# Inverted indexing 99.59790209790211 %
# Inverted indexing 99.60227272727272 %
# Inverted indexing 99.60664335664336 %
# Inverted indexing 99.61101398601399 %
# Inverted indexing 99.61538461538461 %
# Inverted indexing 99.61975524475525 %
# Inverted indexing 99.62412587412588 %
# Inverted indexing 99.6284965034965 %
# Inverted indexing 99.63286713286713 %
# Inverted indexing 99.63723776223776 %
# Inverted indexing 99.6416083916084 %
# Inverted indexing 99.64597902097903 %
# Inverted indexing 99.65034965034964 %
# Inverted indexing 99.65472027972028 %
# Inverted indexing 99.6590909090909 %
# Inverted indexing 99.66346153846153 %
# Inverted indexing 99.66783216783217 %
# Inverted indexing 99.6722027972028 %
# Inverted indexing 99.67657342657343 %
# Inverted indexing 99.68094405594405 %
# Inverted indexing 99.68531468531468 %
# Inverted indexing 99.68968531468532 %
# Inverted indexing 99.69405594405595 %
# Inverted indexing 99.69842657342657 %
# Inverted indexing 99.7027972027972 %
# Inverted indexing 99.70716783216783 %
# Inverted indexing 99.71153846153847 %
# Inverted indexing 99.7159090909091 %
# Inverted indexing 99.72027972027972 %
# Inverted indexing 99.72465034965035 %
# Inverted indexing 99.72902097902097 %
# Inverted indexing 99.73339160839161 %
# Inverted indexing 99.73776223776224 %
# Inverted indexing 99.74213286713287 %
# Inverted indexing 99.7465034965035 %
# Inverted indexing 99.75087412587412 %
# Inverted indexing 99.75524475524476 %
# Inverted indexing 99.75961538461539 %
# Inverted indexing 99.76398601398601 %
# Inverted indexing 99.76835664335665 %
# Inverted indexing 99.77272727272727 %
# Inverted indexing 99.77709790209789 %
# Inverted indexing 99.78146853146853 %
# Inverted indexing 99.78583916083916 %
# Inverted indexing 99.7902097902098 %
# Inverted indexing 99.79458041958041 %
# Inverted indexing 99.79895104895104 %
# Inverted indexing 99.80332167832168 %
# Inverted indexing 99.8076923076923 %
# Inverted indexing 99.81206293706293 %
# Inverted indexing 99.81643356643357 %
# Inverted indexing 99.82080419580419 %
# Inverted indexing 99.82517482517483 %
# Inverted indexing 99.82954545454545 %
# Inverted indexing 99.83391608391608 %
# Inverted indexing 99.83828671328672 %
# Inverted indexing 99.84265734265733 %
# Inverted indexing 99.84702797202797 %
# Inverted indexing 99.8513986013986 %
# Inverted indexing 99.85576923076923 %
# Inverted indexing 99.86013986013987 %
# Inverted indexing 99.8645104895105 %
# Inverted indexing 99.86888111888112 %
# Inverted indexing 99.87325174825175 %
# Inverted indexing 99.87762237762237 %
# Inverted indexing 99.88199300699301 %
# Inverted indexing 99.88636363636364 %
# Inverted indexing 99.89073426573427 %
# Inverted indexing 99.8951048951049 %
# Inverted indexing 99.89947552447552 %
# Inverted indexing 99.90384615384616 %
# Inverted indexing 99.90821678321679 %
# Inverted indexing 99.91258741258741 %
# Inverted indexing 99.91695804195804 %
# Inverted indexing 99.92132867132867 %
# Inverted indexing 99.9256993006993 %
# Inverted indexing 99.93006993006993 %
# Inverted indexing 99.93444055944056 %
# Inverted indexing 99.9388111888112 %
# Inverted indexing 99.94318181818181 %
# Inverted indexing 99.94755244755244 %
# Inverted indexing 99.95192307692308 %
# Inverted indexing 99.9562937062937 %
# Inverted indexing 99.96066433566433 %
# Inverted indexing 99.96503496503496 %
# Inverted indexing 99.96940559440559 %
# Inverted indexing 99.97377622377623 %
# Inverted indexing 99.97814685314685 %
# Inverted indexing 99.98251748251748 %
# Inverted indexing 99.98688811188812 %
# Inverted indexing 99.99125874125873 %
# Inverted indexing 99.99562937062937 %
# Inverted indexing 100.0 %

# %% [markdown]
# Showing inverted index

# %%
# inverted_index_df = pd.read_csv("/content/gdrive/MyDrive/Posting_Lists.csv")
news_df.iloc[284652]["NewsBody"]
# Out:
# '\ufeffمسوول فضای مجازی سراج چهارمحال و بختیاری گفت: فریب عملیات روانی دشمن را نخوریم.'

# %% [markdown]
# Runing Query and Retrive

# %%
#running IR
# news_df = pd.read_csv("/content/gdrive/MyDrive/PreProcessedNews.csv")
# inverted_index_df = pd.read_csv("/content/gdrive/MyDrive/Posting_Lists.csv")
get_query(news_df, inverted_index_df, 1000)
# inverted_index_df.head(10)
# Out:
# Enter your query: فریب
# Enter your Weighting model: (e.g. : ddd.qqq)
# How many Document do you want to Retrive : 10
# Preprocessed 0
# 0  ::::::  0         ﻿محمد نوری در گفت\r\nوگو\r\nبا خبرنگار ورزشی خ...
# 1         ﻿به گزارش گروه بین‌الملل خبرگزاری فارس، با امض...
# 2         ﻿به گزارش خبرگزاری فارس از شیراز، سیدابراهیم ح...
# 3         ﻿حجت‌الاسلام جعفر جنتی امروز در گفت‌وگو با خبر...
# 4         ﻿به گزارش خبرنگار گروه علمی و دانشگاهی خبرگزار...
#                                 ...
# 285690    ﻿به گزارش خبرگزاری فارس از همدان، آیت‌الله غیا...
# 285691    ﻿به گزارش خبرگزاری فارس، علیرضا جهانبخش پس از ...
# 285692    ﻿به گزارش خبرگزاری فارس از قرچک، حجت‌الاسلام و...
# 285693    ﻿به گزارش خبرگزاری فارس از پاکدشت، حجت‌الاسلام...
# 285694    ﻿احمدامیرآبادی فراهانی در گفت‌وگو با خبرنگار ف...
# Name: NewsBody, Length: 285695, dtype: object
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c848994b896a> in <module>
#       2 # news_df = pd.read_csv("/content/gdrive/MyDrive/PreProcessedNews.csv")
#       3 # inverted_index_df = pd.read_csv("/content/gdrive/MyDrive/Posting_Lists.csv")
# ----> 4 get_query(news_df, inverted_index_df, 1000)
#       5 # inverted_index_df.head(10)
#
# <ipython-input-22-a07d69247065> in get_query(preprocessed_df, inverted_index, number_of_documents)
#     260             print(i, " :::::: ", preprocessed_df['NewsBody'])
#     261             print("----------------------------------------------------------")
# --> 262             similarity = np.argwhere(maxim > x)
#     263
#     264
#
# NameError: name 'x' is not defined
